# %%
from socialgene.neo4j.neo4j import GraphDriver # grab the the neo4j connection
from socialgene.config import env_vars
import pandas as pd
from socialgene.base.socialgene import SocialGene

env_vars["NEO4J_URI"] = "bolt://localhost:7688"
pd.set_option('display.max_rows', 100)

# %% [markdown]
# > Note: While timings here are fast, they also include latency between my computer in Chicago and the server in Madison, WI.

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
                MATCH 
                    (h1:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(hmm:hmm),
                    (hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)
                where n1.external_id starts with "BGC"
                RETURN  
                        h1.acc as hmm_acc,
                        h1.description as description,
                        n1.external_id as nucelotide_id,
                        e1.locus_tag as locus_tag,
                        e1.external_id as protein_id,
                        e1.description
        """,
        ).to_df()

df
# Out:
# 2024-06-13 17:07:06 INFO     Connected to Neo4j database at bolt://localhost:7688                                                          ]8;id=666239;file:///home/chase/Documents/github/kwan_lab/socialgene/sgpy/socialgene/neo4j/neo4j.py\neo4j.py]8;;\:]8;id=285235;file:///home/chase/Documents/github/kwan_lab/socialgene/sgpy/socialgene/neo4j/neo4j.py#61\61]8;;\
# CPU times: user 11.2 ms, sys: 261 µs, total: 11.5 ms
# Wall time: 591 ms
#       hmm_acc         description nucelotide_id   locus_tag  protein_id  \
# 0  PF00227.29  Proteasome subunit    BGC0000145        None  ABP73653.1
# 1  PF00227.29  Proteasome subunit    BGC0000345        None  AHB38505.1
# 2  PF00227.29  Proteasome subunit    BGC0000971        None  CBW54670.1
# 3  PF00227.29  Proteasome subunit    BGC0001041  Strop_1015  ABP53490.1
# 4  PF00227.29  Proteasome subunit    BGC0001202        None  AKA59433.1
# 5  PF00227.29  Proteasome subunit    BGC0001203        None  AKA59451.1
# 6  PF00227.29  Proteasome subunit    BGC0001399  ANIA_03493  CBF76042.1
# 7  PF00227.29  Proteasome subunit    BGC0001829        None  CUX96950.1
#
#                      e1.description
# 0                              SalI
# 1           proteasome beta-subunit
# 2       20S proteasome beta-subunit
# 3  20S proteasome, A and B subunits
# 4           proteasome subunit beta
# 5           proteasome subunit beta
# 6    conserved hypothetical protein
# 7                              TmcC

# %% [markdown]
# Count the number of total non MIBiG BGCs

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
        MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
        where e1.antismash_region is not null and not n1.external_id starts with "BGC" 
        WITH a1, n1, COUNT(DISTINCT(e1.antismash_region)) as ar_in_nuc
        RETURN sum(ar_in_nuc) as count
        
        """,
        ).value()

df[0]
# Out:
# CPU times: user 2.12 ms, sys: 0 ns, total: 2.12 ms
# Wall time: 1.54 s
# 1595

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
        MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
        where e1.antismash_region is not null and not n1.external_id starts with "BGC" 
        RETURN 
            count(DISTINCT a1.superkingdom) as superkingdom_count,
            count(DISTINCT a1.phylum) as phylum_count,
            count(DISTINCT a1.class) as class_count,
            count(DISTINCT a1.order) as order_count,
            count(DISTINCT a1.family) as family_count,
            count(DISTINCT a1.genus) as genus_count           
        """,
        ).to_df()
df
# Out:
# CPU times: user 204 µs, sys: 3.39 ms, total: 3.6 ms
# Wall time: 1.5 s
#    superkingdom_count  phylum_count  class_count  order_count  family_count  \
# 0                   3            25           44           93           167
#
#    genus_count
# 0          280

# %% [markdown]
# All BGC types

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
        MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
        where e1.antismash_region is not null and not n1.external_id starts with "BGC" 
        WITH distinct a1, n1, e1.antismash_region as ar, apoc.coll.sort(e1.antismash_products) as ap
        WITH collect(ap) as zz
        with apoc.coll.frequenciesAsMap(zz) as w
        unwind keys(w) as ww
        return ww as bgc_type, w[ww] as count order by count DESC
        """,
        ).to_df()

df
# Out:
# CPU times: user 7.28 ms, sys: 93 µs, total: 7.37 ms
# Wall time: 1.52 s
#                                              bgc_type  count
# 0                                           [ectoine]    257
# 1                                         [NRPS-like]    225
# 2                                             [T3PKS]    123
# 3                                           [terpene]    107
# 4                                             [T1PKS]     81
# 5                                       [NRPS, T1PKS]     74
# 6                                              [NRPS]     72
# 7                           [arylpolyene, resorcinol]     69
# 8                                  [NRPS-like, T1PKS]     65
# 9                                       [arylpolyene]     57
# 10                           [NRP-metallophore, NRPS]     38
# 11                                 [fungal-RiPP-like]     36
# 12                                   [T1PKS, hglE-KS]     34
# 13                                      [betalactone]     28
# 14                                        [RiPP-like]     27
# 15                                 [acyl_amino_acids]     19
# 16                    [acyl_amino_acids, hserlactone]     17
# 17                           [NRPS, NRPS-like, T1PKS]     16
# 18                                            [T2PKS]     15
# 19                                   [T1PKS, terpene]     15
# 20                                          [hglE-KS]     12
# 21                                   [redox-cofactor]     11
# 22                                   [RRE-containing]     11
# 23                            [lanthipeptide-class-v]     11
# 24                               [RiPP-like, terpene]      8
# 25                                      [hserlactone]      8
# 26                                              [LAP]      7
# 27                                            [NAGGN]      7
# 28                                      [thiopeptide]      7
# 29               [NRPS-like, T1PKS, transAT-PKS-like]      7
# 30                                     [T1PKS, T2PKS]      6
# 31                                            [NAPAA]      6
# 32                                   [NI-siderophore]      6
# 33                                   [T3PKS, terpene]      6
# 34                                             [CDPS]      5
# 35                                      [cyanobactin]      4
# 36                                        [proteusin]      4
# 37         [NRP-metallophore, NRPS, acyl_amino_acids]      4
# 38                      [T1PKS, betalactone, hglE-KS]      4
# 39                                      [phosphonate]      4
# 40                                 [phosphonate-like]      4
# 41                           [NRPS-like, betalactone]      3
# 42                 [arylpolyene, resorcinol, terpene]      3
# 43                                [NRPS, hserlactone]      3
# 44                                            [other]      3
# 45                   [NRPS, betalactone, transAT-PKS]      3
# 46                                     [lassopeptide]      3
# 47                                  [NRPS, NRPS-like]      3
# 48                        [thioamitides, thiopeptide]      2
# 49                                           [indole]      2
# 50  [NRPS, NRPS-like, PKS-like, T1PKS, transAT-PKS...      2
# 51                                         [PKS-like]      2
# 52                    [NRP-metallophore, NRPS, T1PKS]      2
# 53                   [NRPS, PKS-like, T1PKS, terpene]      2
# 54                                             [2dos]      2
# 55                             [NI-siderophore, NRPS]      2
# 56                       [cyclic-lactone-autoinducer]      2
# 57                             [NRPS, T1PKS, terpene]      2
# 58                      [LAP, proteusin, thiopeptide]      1
# 59      [NRPS-like, T1PKS, hglE-KS, transAT-PKS-like]      1
# 60                                     [thioamitides]      1
# 61         [NRPS, NRPS-like, T1PKS, transAT-PKS-like]      1
# 62         [NRPS-like, RiPP-like, T1PKS, transAT-PKS]      1
# 63                                       [epipeptide]      1
# 64                               [NRPS-like, terpene]      1
# 65                     [NRPS, NRPS-like, transAT-PKS]      1
# 66                    [NRPS, T1PKS, fungal-RiPP-like]      1
# 67                          [T1PKS, fungal-RiPP-like]      1
# 68         [NRP-metallophore, NRPS, NRPS-like, T1PKS]      1
# 69                 [arylpolyene, ectoine, resorcinol]      1
# 70           [NRPS, NRPS-like, T1PKS, T3PKS, terpene]      1
# 71                                       [isocyanide]      1
# 72  [NRPS, NRPS-like, T1PKS, betalactone, transAT-...      1
# 73                           [NRPS-like, transAT-PKS]      1
# 74                           [lanthipeptide-class-iv]      1
# 75                  [T1PKS, hglE-KS, oligosaccharide]      1
# 76                  [NRPS, fungal-RiPP-like, terpene]      1
# 77                                   [isocyanide-nrp]      1
# 78                                 [mycosporine-like]      1
# 79                                      [fungal-RiPP]      1
# 80                                 [NAPAA, NRPS-like]      1
# 81                      [NRPS, T1PKS, T3PKS, terpene]      1
# 82      [LAP, NRPS, T1PKS, thioamitides, thiopeptide]      1
# 83                                 [LAP, thiopeptide]      1
# 84                                    [methanobactin]      1
# 85                                        [linaridin]      1
# 86                [NRPS, NRPS-like, T1PKS, phenazine]      1
# 87                         [PKS-like, T1PKS, terpene]      1
# 88                                    [ranthipeptide]      1
# 89                        [T1PKS, T2PKS, transAT-PKS]      1
# 90                           [NRPS, fungal-RiPP-like]      1
# 91                                 [transAT-PKS-like]      1
# 92                    [fungal-RiPP, fungal-RiPP-like]      1
# 93                                     [NAGGN, T1PKS]      1
# 94                                     [T1PKS, T3PKS]      1

# %% [markdown]
# Bacterial BGC types

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
        MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
        where e1.antismash_region is not null and not n1.external_id starts with "BGC" 
        WITH distinct a1, n1, e1.antismash_region as ar, apoc.coll.sort(e1.antismash_products) as ap
        where a1.superkingdom="Bacteria"
        WITH collect(ap) as zz
        with apoc.coll.frequenciesAsMap(zz) as w
        unwind keys(w) as ww
        return ww as bgc_type, w[ww] as count ORDER BY count DESC 
        """,
        ).to_df()

df
# Out:
# CPU times: user 6.65 ms, sys: 187 µs, total: 6.83 ms
# Wall time: 1.5 s
#                                              bgc_type  count
# 0                                           [ectoine]    257
# 1                                         [NRPS-like]    180
# 2                                             [T3PKS]    120
# 3                                           [terpene]     78
# 4                                       [NRPS, T1PKS]     70
# 5                           [arylpolyene, resorcinol]     69
# 6                                  [NRPS-like, T1PKS]     57
# 7                                       [arylpolyene]     57
# 8                                             [T1PKS]     48
# 9                                              [NRPS]     42
# 10                                   [T1PKS, hglE-KS]     34
# 11                                        [RiPP-like]     23
# 12                                 [acyl_amino_acids]     19
# 13                    [acyl_amino_acids, hserlactone]     17
# 14                                      [betalactone]     16
# 15                                            [T2PKS]     15
# 16                           [NRPS, NRPS-like, T1PKS]     15
# 17                                   [T1PKS, terpene]     13
# 18                                          [hglE-KS]     12
# 19                                   [redox-cofactor]     11
# 20                            [lanthipeptide-class-v]     11
# 21                               [RiPP-like, terpene]      8
# 22                                      [hserlactone]      8
# 23                                              [LAP]      7
# 24                                            [NAGGN]      7
# 25               [NRPS-like, T1PKS, transAT-PKS-like]      7
# 26                                     [T1PKS, T2PKS]      6
# 27                                            [NAPAA]      6
# 28                                   [T3PKS, terpene]      6
# 29                                             [CDPS]      5
# 30                                      [cyanobactin]      4
# 31                                        [proteusin]      4
# 32         [NRP-metallophore, NRPS, acyl_amino_acids]      4
# 33                      [T1PKS, betalactone, hglE-KS]      4
# 34                                      [phosphonate]      4
# 35                                   [NI-siderophore]      4
# 36                                 [phosphonate-like]      4
# 37                           [NRPS-like, betalactone]      3
# 38                 [arylpolyene, resorcinol, terpene]      3
# 39                                [NRPS, hserlactone]      3
# 40                                            [other]      3
# 41                           [NRP-metallophore, NRPS]      3
# 42                   [NRPS, betalactone, transAT-PKS]      3
# 43                                     [lassopeptide]      3
# 44                                  [NRPS, NRPS-like]      3
# 45                                   [RRE-containing]      2
# 46                                           [indole]      2
# 47  [NRPS, NRPS-like, PKS-like, T1PKS, transAT-PKS...      2
# 48                                         [PKS-like]      2
# 49                    [NRP-metallophore, NRPS, T1PKS]      2
# 50                   [NRPS, PKS-like, T1PKS, terpene]      2
# 51                                             [2dos]      2
# 52                             [NI-siderophore, NRPS]      2
# 53                       [cyclic-lactone-autoinducer]      2
# 54                             [NRPS, T1PKS, terpene]      2
# 55                      [LAP, proteusin, thiopeptide]      1
# 56      [NRPS-like, T1PKS, hglE-KS, transAT-PKS-like]      1
# 57         [NRPS, NRPS-like, T1PKS, transAT-PKS-like]      1
# 58         [NRPS-like, RiPP-like, T1PKS, transAT-PKS]      1
# 59                                       [epipeptide]      1
# 60                               [NRPS-like, terpene]      1
# 61                     [NRPS, NRPS-like, transAT-PKS]      1
# 62         [NRP-metallophore, NRPS, NRPS-like, T1PKS]      1
# 63                 [arylpolyene, ectoine, resorcinol]      1
# 64           [NRPS, NRPS-like, T1PKS, T3PKS, terpene]      1
# 65  [NRPS, NRPS-like, T1PKS, betalactone, transAT-...      1
# 66                           [NRPS-like, transAT-PKS]      1
# 67                        [thioamitides, thiopeptide]      1
# 68                           [lanthipeptide-class-iv]      1
# 69                  [T1PKS, hglE-KS, oligosaccharide]      1
# 70                                 [mycosporine-like]      1
# 71                                 [NAPAA, NRPS-like]      1
# 72                      [NRPS, T1PKS, T3PKS, terpene]      1
# 73      [LAP, NRPS, T1PKS, thioamitides, thiopeptide]      1
# 74                                    [methanobactin]      1
# 75                [NRPS, NRPS-like, T1PKS, phenazine]      1
# 76                         [PKS-like, T1PKS, terpene]      1
# 77                                    [ranthipeptide]      1
# 78                        [T1PKS, T2PKS, transAT-PKS]      1
# 79                                      [thiopeptide]      1
# 80                                 [transAT-PKS-like]      1
# 81                                     [NAGGN, T1PKS]      1
# 82                                     [T1PKS, T3PKS]      1

# %% [markdown]
# Eukaryota BGC types

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
        MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
        where e1.antismash_region is not null and not n1.external_id starts with "BGC" 
        WITH distinct a1, n1, e1.antismash_region as ar, apoc.coll.sort(e1.antismash_products) as ap
        where a1.superkingdom="Eukaryota"
        WITH collect(ap) as zz
        with apoc.coll.frequenciesAsMap(zz) as w
        unwind keys(w) as ww
        return ww as bgc_type, w[ww] as count ORDER BY count DESC 
        """,
        ).to_df()

df
# Out:
# CPU times: user 3.25 ms, sys: 0 ns, total: 3.25 ms
# Wall time: 1.4 s
#                              bgc_type  count
# 0                         [NRPS-like]     45
# 1                  [fungal-RiPP-like]     36
# 2            [NRP-metallophore, NRPS]     35
# 3                             [T1PKS]     32
# 4                              [NRPS]     25
# 5                           [terpene]     13
# 6                  [NRPS-like, T1PKS]      7
# 7                       [NRPS, T1PKS]      4
# 8                             [T3PKS]      3
# 9                    [T1PKS, terpene]      2
# 10  [NRPS, fungal-RiPP-like, terpene]      1
# 11                   [isocyanide-nrp]      1
# 12                       [isocyanide]      1
# 13                      [fungal-RiPP]      1
# 14           [NRPS, fungal-RiPP-like]      1
# 15    [NRPS, T1PKS, fungal-RiPP-like]      1
# 16          [T1PKS, fungal-RiPP-like]      1
# 17    [fungal-RiPP, fungal-RiPP-like]      1
# 18           [NRPS, NRPS-like, T1PKS]      1

# %% [markdown]
# Archaea BGC types

# %%
# %%time
with GraphDriver() as db:
        df = db.run(
            """
        MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
        where e1.antismash_region is not null and not n1.external_id starts with "BGC" 
        WITH distinct a1, n1, e1.antismash_region as ar, apoc.coll.sort(e1.antismash_products) as ap
        where a1.superkingdom = "Archaea" 
        WITH collect(ap) as zz
        with apoc.coll.frequenciesAsMap(zz) as w
        unwind keys(w) as ww
        return ww as bgc_type, w[ww] as count ORDER BY count DESC 
        """,
        ).to_df()

df
# Out:
# CPU times: user 2.9 ms, sys: 0 ns, total: 2.9 ms
# Wall time: 1.54 s
#                        bgc_type  count
# 0                     [terpene]     14
# 1                 [betalactone]     12
# 2              [RRE-containing]      9
# 3                 [thiopeptide]      6
# 4                        [NRPS]      5
# 5                   [RiPP-like]      4
# 6              [NI-siderophore]      2
# 7                   [linaridin]      1
# 8                [thioamitides]      1
# 9   [thioamitides, thiopeptide]      1
# 10           [LAP, thiopeptide]      1

# %% [markdown]
# Grab the BGC clusters from the SocialGene database and create genbank files for each cluster

# %%
# %%time
with GraphDriver() as db:
    res = db.run(
        """
    MATCH (:hmm_source {acc:"PF00227.29"})-[:SOURCE_DB]-(:hmm)-[:ANNOTATES]->(:protein)<-[e1:ENCODES]-(n1:nucleotide)-[:ASSEMBLES_TO]-(a1:assembly)
    where e1.antismash_region is not null and not n1.external_id starts with "BGC"
    WITH DISTINCT n1, e1.antismash_region as ar
    MATCH (n1)-[e1:ENCODES]-(p1:protein)
    WHERE e1.antismash_region = ar
    WITH n1, e1.antismash_region as ar,  e1.antismash_products as type, min(e1.start) as start, max(e1.end) as end 
    RETURN n1.uid as nucelotide_id, n1.external_id as external_id, ar as region, type, start, end 
    """,
    ).data()
# Out:
# CPU times: user 77.8 ms, sys: 8.19 ms, total: 86 ms
# Wall time: 3.42 s

# %%
sg = SocialGene()

# %%
for i in res:
    z = sg.fill_given_locus_range(locus_uid=i["nucelotide_id"], start=i["start"], end=i["end"])
    sg.assemblies[z['assembly']].loci[z['locus']].add_bgcs_by_start_end(start=i["start"], end=i["end"], uid=f'{i["region"]}_{"-".join(i["type"])}')

# %%
sg.add_sequences_from_neo4j()

# %%
for ak,av in sg.assemblies.items():
    for nk,nv in av.loci.items():
        for gene_cluster in nv.gene_clusters:
            gene_cluster.write_genbank(f"bgc_gbk/{ak}_{nv.external_id}_{gene_cluster.uid}.gbk")
